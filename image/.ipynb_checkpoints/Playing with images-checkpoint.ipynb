# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open("rock.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x491 at 0xBBDEEB0>

# %%
plt.imshow(img)

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=474x491 at 0xBC67690>

# %%
img.rotate(-90) == img.rotate(270)
# Out:
# True

# %% [markdown]
# # type of the image

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# # changing it to an array

# %%
img_array = np.asarray(img)

# %%
type(img_array)
# Out:
# numpy.ndarray

# %%
plt.imshow(img_array)
